# %%
# import necessary libraries
import numpy as np

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, Column, Integer, String, Float, inspect

import json

from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)

from flask_sqlalchemy import SQLAlchemy
#################################################
# Flask Setup
#################################################
app = Flask(__name__)

#################################################
# Database Setup
#################################################
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] = "sqlite:///diabetes.sqlite"
db = SQLAlchemy(app)

class Data(db.Model):
    __tablename__ = 'data'
    id = Column(Integer, primary_key=True)
    Year = Column(Integer)
    LocationAbbr = Column(String(255))
    LocationDesc = Column(String(255))
    Question = Column(String(255))
    DataValue = Column(Float)
    Gender = Column(String(255))
    Average = Column(Integer)
    AbbrQuestion = Column(String(255))
# Out:
# C:\Users\alfan\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\flask_sqlalchemy\__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
data_query = db.session.query(Data.Year, Data.LocationAbbr, Data.LocationDesc, Data.Question, Data.DataValue, Data.Gender, Data.Average, Data.AbbrQuestion).all()

# %%
list = []
x = 0
for d in data_query:
    query = {}
    query["Year"] = data_query[x][0]
    query["LocationAbbr"] = data_query[x][1]
    query["LocationDesc"] = data_query[x][2]
    query["Question"] = data_query[x][3]
    query["DataValue"] = data_query[x][4]
    query["Gender"] = data_query[x][5]
    query["Average"] = data_query[x][6]
    query["AbbrQuestion"] = data_query[x][7]
    list.append(query)
    x+=1

# %%
x = 0
for item in list:
    print("{")
    print(f'DataValue: {list[x]["DataValue"]},')
    print(f'Gender: "{list[x]["Gender"]}",')
    print(f'LocationAbbr: "{list[x]["LocationAbbr"]}",')
    print(f'LocationDesc: "{list[x]["LocationDesc"]}",')
    print(f'Question: "{list[x]["Question"]}",')
    print(f'Average: {list[x]["Average"]},')
    print(f'AbbrQuestion: "{list[x]["AbbrQuestion"]}",')
    print(f'Year: {list[x]["Year"]}')
    print("},")
    x+=1
# Out:
# {
# DataValue: 79.4,
# Gender: "Female",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 78.6,
# Gender: "Female",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 78.1,
# Gender: "Female",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 77.8,
# Gender: "Overall",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 77.6,
# Gender: "Overall",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 77.5,
# Gender: "Male",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 77.3,
# Gender: "Overall",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 75.8,
# Gender: "Male",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 75.6,
# Gender: "Male",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 75.3,
# Gender: "Male",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 74.0,
# Gender: "Overall",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 72.9,
# Gender: "Female",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 70.1,
# Gender: "Female",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 68.7,
# Gender: "Male",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 68.2,
# Gender: "Overall",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 67.9,
# Gender: "Female",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 67.8,
# Gender: "Overall",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 65.3,
# Gender: "Male",
# LocationAbbr: "AL",
# LocationDesc: "Alabama",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 43.45833333333333,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 82.3,
# Gender: "Male",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 77.2,
# Gender: "Female",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 75.9,
# Gender: "Overall",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 74.2,
# Gender: "Male",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 71.1,
# Gender: "Male",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 70.3,
# Gender: "Overall",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 69.5,
# Gender: "Overall",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 68.2,
# Gender: "Female",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 66.2,
# Gender: "Male",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 63.9,
# Gender: "Overall",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 63.9,
# Gender: "Female",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 63.4,
# Gender: "Male",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 62.6,
# Gender: "Overall",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 59.0,
# Gender: "Female",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 57.7,
# Gender: "Male",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 57.3,
# Gender: "Overall",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 56.8,
# Gender: "Female",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 56.1,
# Gender: "Female",
# LocationAbbr: "AK",
# LocationDesc: "Alaska",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 36.91944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 71.0,
# Gender: "Male",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.5,
# Gender: "Female",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 70.3,
# Gender: "Overall",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 69.6,
# Gender: "Female",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 68.7,
# Gender: "Female",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 68.2,
# Gender: "Female",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 68.0,
# Gender: "Overall",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 67.1,
# Gender: "Overall",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 66.6,
# Gender: "Female",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 66.5,
# Gender: "Overall",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 66.1,
# Gender: "Female",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 66.0,
# Gender: "Male",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 65.7,
# Gender: "Male",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 65.3,
# Gender: "Overall",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 65.2,
# Gender: "Overall",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 64.7,
# Gender: "Male",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 64.1,
# Gender: "Male",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.0,
# Gender: "Male",
# LocationAbbr: "AZ",
# LocationDesc: "Arizona",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.6861111111111,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 80.7,
# Gender: "Male",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 78.0,
# Gender: "Overall",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 77.3,
# Gender: "Female",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 75.9,
# Gender: "Female",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 75.1,
# Gender: "Male",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 73.9,
# Gender: "Overall",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 73.8,
# Gender: "Overall",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 72.3,
# Gender: "Female",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 71.6,
# Gender: "Male",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 71.1,
# Gender: "Male",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 70.5,
# Gender: "Male",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.3,
# Gender: "Overall",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 69.7,
# Gender: "Female",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 68.9,
# Gender: "Male",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 67.4,
# Gender: "Overall",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 66.4,
# Gender: "Overall",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 63.5,
# Gender: "Female",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 63.1,
# Gender: "Female",
# LocationAbbr: "AR",
# LocationDesc: "Arkansas",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.886111111111106,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 71.0,
# Gender: "Male",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.6,
# Gender: "Overall",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.3,
# Gender: "Female",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.1,
# Gender: "Male",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 69.6,
# Gender: "Female",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 69.6,
# Gender: "Overall",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 69.5,
# Gender: "Male",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 69.2,
# Gender: "Female",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 68.2,
# Gender: "Overall",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 67.5,
# Gender: "Female",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 66.9,
# Gender: "Female",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 66.6,
# Gender: "Overall",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 65.4,
# Gender: "Female",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.5,
# Gender: "Overall",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 64.0,
# Gender: "Male",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 62.3,
# Gender: "Overall",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 61.6,
# Gender: "Male",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 59.5,
# Gender: "Male",
# LocationAbbr: "CA",
# LocationDesc: "California",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.46111111111114,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 70.4,
# Gender: "Female",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 70.0,
# Gender: "Overall",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 69.7,
# Gender: "Male",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 68.9,
# Gender: "Female",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 67.2,
# Gender: "Female",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 65.9,
# Gender: "Female",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 65.7,
# Gender: "Overall",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 65.1,
# Gender: "Overall",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 64.9,
# Gender: "Male",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 64.3,
# Gender: "Female",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 63.6,
# Gender: "Overall",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 63.4,
# Gender: "Male",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 63.2,
# Gender: "Male",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 63.1,
# Gender: "Overall",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 62.2,
# Gender: "Female",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 61.8,
# Gender: "Overall",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 60.6,
# Gender: "Male",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 59.7,
# Gender: "Male",
# LocationAbbr: "CO",
# LocationDesc: "Colorado",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 35.93333333333334,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 77.1,
# Gender: "Female",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 75.3,
# Gender: "Overall",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 73.8,
# Gender: "Male",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 72.6,
# Gender: "Female",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 71.8,
# Gender: "Male",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 71.2,
# Gender: "Overall",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 70.9,
# Gender: "Overall",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.6,
# Gender: "Female",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 69.3,
# Gender: "Male",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 68.3,
# Gender: "Female",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 67.4,
# Gender: "Female",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 67.3,
# Gender: "Overall",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 66.5,
# Gender: "Male",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 65.2,
# Gender: "Overall",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 64.3,
# Gender: "Female",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 63.6,
# Gender: "Overall",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 63.3,
# Gender: "Male",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 62.9,
# Gender: "Male",
# LocationAbbr: "CT",
# LocationDesc: "Connecticut",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.086111111111094,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 76.7,
# Gender: "Female",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 75.1,
# Gender: "Female",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 74.9,
# Gender: "Overall",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 74.7,
# Gender: "Female",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 73.2,
# Gender: "Overall",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 73.0,
# Gender: "Overall",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 72.9,
# Gender: "Male",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 71.3,
# Gender: "Male",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 71.1,
# Gender: "Male",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 68.8,
# Gender: "Male",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 68.2,
# Gender: "Male",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 67.9,
# Gender: "Male",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 67.9,
# Gender: "Overall",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 67.0,
# Gender: "Female",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 66.7,
# Gender: "Overall",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 65.8,
# Gender: "Overall",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 65.5,
# Gender: "Female",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 63.4,
# Gender: "Female",
# LocationAbbr: "DE",
# LocationDesc: "Delaware",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 40.41944444444443,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 82.8,
# Gender: "Female",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 80.3,
# Gender: "Female",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 78.1,
# Gender: "Female",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 75.8,
# Gender: "Overall",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 75.6,
# Gender: "Overall",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 74.1,
# Gender: "Overall",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 71.1,
# Gender: "Male",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 71.0,
# Gender: "Overall",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 70.9,
# Gender: "Female",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 69.7,
# Gender: "Male",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 69.6,
# Gender: "Male",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 66.9,
# Gender: "Female",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 66.2,
# Gender: "Male",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 65.9,
# Gender: "Overall",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.7,
# Gender: "Male",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 59.1,
# Gender: "Female",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 57.9,
# Gender: "Overall",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 56.3,
# Gender: "Male",
# LocationAbbr: "DC",
# LocationDesc: "District of Columbia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 39.025,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 76.9,
# Gender: "Male",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 76.2,
# Gender: "Male",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 75.9,
# Gender: "Female",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 75.3,
# Gender: "Overall",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 74.9,
# Gender: "Overall",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 74.8,
# Gender: "Overall",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 74.7,
# Gender: "Male",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 73.6,
# Gender: "Female",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 72.5,
# Gender: "Female",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 71.0,
# Gender: "Male",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 70.4,
# Gender: "Overall",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 69.8,
# Gender: "Female",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 66.0,
# Gender: "Female",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 65.9,
# Gender: "Overall",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 65.8,
# Gender: "Male",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 65.2,
# Gender: "Male",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 63.9,
# Gender: "Overall",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 62.7,
# Gender: "Female",
# LocationAbbr: "FL",
# LocationDesc: "Florida",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.033333333333346,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 81.3,
# Gender: "Female",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 80.3,
# Gender: "Overall",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 79.5,
# Gender: "Female",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 79.2,
# Gender: "Male",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 77.0,
# Gender: "Female",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 76.6,
# Gender: "Overall",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 73.7,
# Gender: "Overall",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 73.4,
# Gender: "Male",
# LocationAbbr: "GA",
# LocationDesc: "Georgia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 41.35277777777776,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.8,
# Gender: "Female",
# ...
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 67.5,
# Gender: "Female",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 65.3,
# Gender: "Female",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 65.3,
# Gender: "Overall",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 65.2,
# Gender: "Male",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.7,
# Gender: "Female",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 61.9,
# Gender: "Male",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 61.7,
# Gender: "Overall",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 61.5,
# Gender: "Female",
# LocationAbbr: "WA",
# LocationDesc: "Washington",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 38.325,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 79.5,
# Gender: "Male",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 77.9,
# Gender: "Overall",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 76.4,
# Gender: "Male",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 76.2,
# Gender: "Female",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 75.7,
# Gender: "Overall",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 75.2,
# Gender: "Female",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 75.0,
# Gender: "Female",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 73.4,
# Gender: "Overall",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 71.3,
# Gender: "Male",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 69.9,
# Gender: "Male",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 69.8,
# Gender: "Female",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 66.0,
# Gender: "Overall",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 66.0,
# Gender: "Overall",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 64.4,
# Gender: "Female",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.2,
# Gender: "Overall",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.1,
# Gender: "Male",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 62.6,
# Gender: "Female",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 62.1,
# Gender: "Male",
# LocationAbbr: "WV",
# LocationDesc: "West Virginia",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 42.069444444444436,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 77.6,
# Gender: "Female",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 77.4,
# Gender: "Overall",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 77.2,
# Gender: "Male",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 73.7,
# Gender: "Female",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 71.1,
# Gender: "Female",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 70.5,
# Gender: "Female",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 67.4,
# Gender: "Female",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 67.2,
# Gender: "Overall",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 66.7,
# Gender: "Overall",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 65.0,
# Gender: "Overall",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 64.5,
# Gender: "Male",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 64.0,
# Gender: "Overall",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 63.5,
# Gender: "Overall",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 62.7,
# Gender: "Male",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 62.7,
# Gender: "Female",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 60.1,
# Gender: "Male",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 60.0,
# Gender: "Male",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 59.4,
# Gender: "Male",
# LocationAbbr: "WI",
# LocationDesc: "Wisconsin",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.97222222222222,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 73.0,
# Gender: "Female",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 72.7,
# Gender: "Female",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 71.9,
# Gender: "Overall",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 71.8,
# Gender: "Overall",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 71.2,
# Gender: "Male",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 71.1,
# Gender: "Male",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2015
# },
# {
# DataValue: 70.9,
# Gender: "Male",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2011
# },
# {
# DataValue: 70.3,
# Gender: "Female",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 68.2,
# Gender: "Female",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 67.1,
# Gender: "Overall",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 66.2,
# Gender: "Overall",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 63.2,
# Gender: "Male",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2015
# },
# {
# DataValue: 63.0,
# Gender: "Female",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Blood Pressure",
# Year: 2013
# },
# {
# DataValue: 62.4,
# Gender: "Overall",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
# {
# DataValue: 62.0,
# Gender: "Female",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 60.2,
# Gender: "Overall",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 58.5,
# Gender: "Male",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2013
# },
# {
# DataValue: 57.3,
# Gender: "Male",
# LocationAbbr: "WY",
# LocationDesc: "Wyoming",
# Question: "Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes",
# Average: 37.60277777777779,
# AbbrQuestion: "Cholesterol",
# Year: 2011
# },
